# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import PIL.Image as Image
import PIL.ImageFont as ImageFont
import PIL.ImageDraw as ImageDraw

# %%
image = np.zeros((1080,1920), dtype = 'uint8')
plt.imshow(image)
plt.show()

# %%
pil_image = Image.fromarray(image)
draw = ImageDraw.Draw(pil_image)
text1 = "\"the quieter you become,"
text2 = "the more you are able to hear.\""
font = ImageFont.truetype('/home/dexter/Downloads/ShmallynFont-Regular (2).ttf',90)

draw.text((1920/2-450,1080/2-150), text1,font = font, fill ="#fff")
draw.text((1920/2-450,1080/2+20), text2,font = font, fill ="#fff")

# %%
new_image = cv2.cvtColor(np.array(pil_image),cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
plt.show()

# %%
cv2.imwrite("wallpaper.jpg",new_image)
# Out:
# True

# %%
new_image.shape
# Out:
# (1080, 1920, 3)

# %%
new_image[350:500,500:1300][:] = 255
plt.imshow(new_image)
plt.show()

# %%
section_img = np.copy(new_image)
r,g,b = cv2.split(section_img)

# text 1
#r[:350,:] += 255
r[680:,:] += 55
g[680:,:] += 55
b[680:,:] += 55

r[:350,:] += 55
g[:350,:] += 55
b[:350,:] += 55

for i in range(460,1,-2):
    r[:,:i] = 50
    g[:,:i] = 50
    b[:,:i] = 50

for i in range(1500,1920,2):
    r[:,i:] = 50
    g[:,i:] = 50
    b[:,i:] = 50

section_img = cv2.merge([r,g,b])
plt.imshow(section_img)
plt.show()

# %%
cv2.imwrite("wallpaper1.jpg",cv2.cvtColor(section_img,cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
section_img.shape
# Out:
# (1080, 1920)

# %%
cv2.rectangle(new_image,(460,350),(1500,680),(255,255,255),5)

plt.imshow(new_image)
plt.show()
